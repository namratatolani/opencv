# %% [markdown]
# https://pysource.com/2018/01/29/bitwise-operators-opencv-3-4-with-python-3-tutorial-7/

# %%
import cv2
import numpy as np

# %%
img1 = cv2.imread("images/drawing_1.png")
img2 = cv2.imread("images/drawing_2.png")
cv2.imshow("img1", img1)
cv2.imshow("img2", img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bitwise_and = cv2.bitwise_and(img1, img2)
cv2.imshow("bitwise and", bitwise_and)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Only white plus white gives white result. Black + white gives black result.

# %%
bitwise_or = cv2.bitwise_or(img1,img2)
cv2.imshow("bitwise or", bitwise_or)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Only black + black is black, rest white

# %%
bitwise_xor = cv2.bitwise_xor(img1, img2)
cv2.imshow("bitwise xor", bitwise_xor)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bitwise_not = cv2.bitwise_not(img1)
cv2.imshow("bitwise not", bitwise_not)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
